# %% [markdown]
# # Submitted by:
#
# * Name 1: Sagi Hirshfeld - 203675319
# * Name 2: Naama Cohen - 205488349

# %% [markdown]
# # paint_the_circle Project
#
# This project identifies and paints circles given in RGB images. Specifically, each input image contains a rectangle, a triangle and a circle. The image is fed into a neural netork, whose outputs are the center and radius of the circle within the image. The domain considered is "[0,1]x[0,1] "box". PyTorch is the platform used. The goal is to paint the circle.
#
# ### **You are given the following files:**
#   Three directories named "train", "validation", and "test" each containing the following:
#   1. a directory called "images" with RGB png files of size 128x128 (so image that is read has shape (3,128,128))
#   2. a file "labels.txt" containing the center points (as x,y) and radius of the circles for all images in "images" directory
#
# Since this problem is somewhat open ended, you are given a suggested structure and some functionality that is already implemented for you (see below). You are not at all obigated to follow this structure or use the code given.
#
# **Note:**
# - "network" and "model" are used interchangeably throughout this documentation.
#
#
# ### **General structure (in order):**
#  1. DataSet and DataLoader            - this is how you load data into the network **(given to you)**
#  2. Neural Network definition         - the class that defines your model   **(need to implement)**
#  3. calculate model parameters number - useful to get a feel for network's size **(given to you)**
#  4. loss function definition          - to be used in training **(need to implement)**
#  5. create an optimizer               - choose your optimizer **(need to implement)**
#  6. estimate number of ops per forward feed - the bigger this is the slower the training **(given to you)**
#  7. estimate ops per forward feed     - use function given to you to estimate this **(implement for convenience)**
#  8. view images and target and net labels - example code to help you see how to use loaders **(given to you)**
#  9. validate_model                   - returns avg loss per image for a model and loader  **(need to implement)**
#  10. train_model                      - trains the network **(need to implement)**
#  11. plot train/validaion losses      - visualizing train and validation losses from training **(given to you)**
#  12. save/load model                  - Allows you to save and load model to disk for later use **(given to you)**
#  13. visualizing images    - Painting circles prodiced by network on images from a given loader **(given to you)**
#
#
# ### ** What you need to do **
# You have 5 (and a half...) things to do:
#  1. Create a CircleNet class, which is your network model. This is a key component. The output of your model should be 3 numbers that represent the the center and radius of the circle in the input image fed into your network. You should keep in mind the number of parameters in your model. If there are too many, it may overfit (and take longer to run). If there are too few, you it may not be able to learn the task needed. A typical structure would have convolutional layers first and fully connected at the end, thus reducing number of parameteres. Consider which activation function you want to use, and whether or not you wish to use batch normalization or dropout. Pooling layers are also possible. Be creative.
#
#  2. Create a loss function. This is another key component as it defines what it means for two circles (the true circle and its estimation) to be similar or not. Namely, two circles (represented by two centers and two radii: ground truth ("labels") and network outputs ("outputs")), whose images look similar should have a smaller loss than two circles whose images look less simialr. Think about how you would quantify "closeness"/"similarity" of circles.
#
#  3. Choose an optimizer. Look here for some ideas: https://pytorch.org/docs/master/optim.html
#
#  4. (This is the "half" thing to do). For your conveinece you may want to use the function calc_ops() that is given to you to calculate an estimate of the number of operations that your network does per feed forward. To do this, you need to enter your own network structure. An example of an arbitrary network is privided to you.
#
#  5. Create a validate_model function that assesses (tests) the performance of a model. It returns the average loss per image for a given loader. It can be run on any set of data (train, validation, or test). You may want to run this function on validation set (loader) from within the train function (see below) train after each epoch so as to see how loss behaves on validation during the training process.
#
#  6. Create a train_model function that trains model. This function updates the following parameteres: model, train_losses, and validation_losses. Model is updated simply by the training processes when optimzer.step() is called. The other two parameteres are lists that hold the average loss per image for the corresponding data (train or validation). After every epoch (i.e., iteration that goes over the entire train data), you should save to these lists the average loss per image for the corresponding data loader. These lists are useful in that you can plot them (functionality given to you) and observe how model behaves. Observe: this fucnton returs nothing, however, it updates parameteres by reference. Specifically, model is updated (trained), and so are train and validation losses values.
#
# **Note:** You are given three sets of data: trian, validation, and test. It is recommended that test not be touched until the very end, and validation be used to get a sense of your network's performance.
#
# ### ** Running on a GPU: **
# It is not necessary to use a GPU for this project. However, if you choose to do so, you will gain a major speedup to your training, which will save you much time. The code given to you identifies the hardware used and will  automatically run on either a GPU or CPU.
#
# ### ** Useful links: **
# 1. PyTorch master tutorial - VERY useful: https://pytorch.org/docs/master/nn.html
# 2. PyTorch optimizers: https://pytorch.org/docs/master/optim.html
# 3. A list of possible reasons why things go wrong: https://blog.slavv.com/37-reasons-why-your-neural-network-is-not-working-4020854bd607#74de
#
# ### ** Final tips: **
# Use the Internet! Things will not work first time. You will get strange error messages. Google them up. The web is  great resource for tackling problems ranging from python error messages, to things not doing what you'd like them to do.
#
#
# ### ** Submission Instructions**
# The project is to be submittd in teams as in the homework. You need to submit the following three files:
# 1. model.dat                            - This is your saved model
# 2. paint_that_circle.ipynb              - This is this notebook containing all of your work
# 3. model.py                             - A file containing your CircleNet class only.
#
# Before you submit, run "check_before_submission.ipynb" to make sure your model could be properly tested. See instructions for running this notebook inside.
#
# Make sure your names appear at the top of this notebook in the appropriate place.
#
# ### **GOOD LUCK!**

# %%
import numpy as np
import PIL.Image as Image
from PIL import ImageDraw
import math

import torch.nn as nn

import torch
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import os
import glob
import datetime

# Device configuration
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Dataset class definition (given to you)

# %%
class ShapesDataset(Dataset):
    
    def __init__(self, dataset_dir):
        """
        Initializing dataset by generating a dicitonary of labels, where an image file name is the key 
        and its labels are the contents of that entry in the dictionary. Images are not loaded. This way it
        is possible to iterate over arbitrarily large datasets (limited by labels dicitonary fitting 
        in memory, which is not a problem in practice)
        
        Args:
            dataset_dir : path to directory with images and labels. In this directory we expect to find
                          a directory called "images" containing the input images, and a file called 
                          "labels.txt" containing desired labels (coefficients)
        """
        
        self.dataset_dir = dataset_dir
        self.labels_dict = self.gen_labels_dict()
        self.images_keys = list(self.labels_dict)  # getting the keys of the dictionary as list
        self.images_keys.sort()                    # sorting so as to have in alphabetical order 

    def __len__(self):
        return len(self.labels_dict)

    def __getitem__(self, index):    
        """
        This funtion makes it possible to iterate over the ShapesDataset
        Args:
            index: running index of images
            
        Returns:
            sample: a dicitionary with three entries:
                    1. 'image'  contains the image
                    2. 'labels' contains labels (coeffs) corresponding to image
                    3. 'fname'  contains name of file (image_key) - may be useful for debugging
        """
        image_key = self.images_keys[index]     # recall - key is the file name of the corresponding image
        image = np.array(Image.open(image_key)) # image has shape: (128, 128, 3)
        image = image/255.0                     # simple normalization - just to maintain small numbers
        image = np.transpose(image, (2, 0, 1))  # network needs RGB channels to be first index
        labels = self.labels_dict[image_key]
        sample = {'image': image, 'labels': labels, 'fname':image_key}
        
        return sample
    
    
    def gen_labels_dict(self):
        """
        This fucntion generates a dictionary of labels
        
        Returns:
            labels_dict: the key is image file name and the value is the corresponding 
            array of labels  
        """
        
        labels_fname = self.dataset_dir + "/labels.txt"
        labels_dict = {}
        with open(labels_fname, "r") as inp:
            for line in inp:
                line = line.split('\n')[0]                                      # remove '\n' from end of line 
                line = line.split(',')
                key  = self.dataset_dir + '/images/' + line[0].strip() + ".png" # image file name is the key
                del line[0]
                
                list_from_line = [float(item) for item in line]
                labels_dict[key] = np.asarray(list_from_line, dtype=np.float32)
                        
        return labels_dict

# %% [markdown]
# # Create Data Loaders (given to you)

# %%
train_dir      = "./train/"
validation_dir = "./validation/"
test_dir       = "./test/"


train_dataset = ShapesDataset(train_dir)

"""
Here we increased the batch size from 32 to 100. Our network uses batch normalization, so using a bigger batch size
normalizes the batch by a mean and variance that better represent the whole dataset. A batch size of 100 is about the biggest
our GPU could handle.
"""
train_loader = DataLoader(train_dataset, 
                          batch_size=100,
                          shuffle=True)

validation_dataset = ShapesDataset(validation_dir)

validation_loader = DataLoader(validation_dataset, 
                               batch_size=1,
                               shuffle=False)

test_dataset = ShapesDataset(test_dir)

test_loader = DataLoader(test_dataset, 
                          batch_size=1,
                          shuffle=False)

print("train loader examples     :", len(train_dataset)) 
print("validation loader examples:", len(validation_dataset))
print("test loader examples      :", len(test_dataset))
# Out:
# train loader examples     : 1000
# validation loader examples: 100
# test loader examples      : 100

# %% [markdown]
# # Neural Network class definition

# %%
# Key modules definition

class Conv_BN_NLA(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride, padding=0):
        super(Conv_BN_NLA, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding)
        self.bn = nn.BatchNorm2d(num_features=out_channels)
        self.activation = nn.ReLU(inplace=True)

    def forward(self, x):
        activation_maps = self.conv(x)
        normalized_activation_maps = self.bn(activation_maps)
        return self.activation(normalized_activation_maps)
    
class Linear_BN_NLA(nn.Module):
    def __init__(self, in_features, out_features):
        super(Linear_BN_NLA, self).__init__()
        self.linear = nn.Linear(in_features, out_features)
        self.bn = nn.BatchNorm1d(num_features=out_features)
        self.activation = nn.ReLU(inplace=True)

    def forward(self, x):
        z1 = self.linear(x)
        z2 = self.bn(z1)
        return self.activation(z2)
    
class Flatten(nn.Module):
    def forward(self, x):
        N, C, H, W = x.size() # read in N, C, H, W
        return x.view(N, -1)  # "flatten" the C * H * W values into a single vector per image

# %%
class CircleNet(nn.Module):
    def __init__(self):
        super(CircleNet, self).__init__()
        self.architecture = nn.Sequential(
                    nn.BatchNorm2d(num_features=3),
                    Conv_BN_NLA(in_channels=3, out_channels=16, kernel_size=3, stride=1, padding=1),
                    Conv_BN_NLA(in_channels=16, out_channels=16, kernel_size=3, stride=1, padding=1),
                    nn.MaxPool2d(kernel_size=2, stride=2),

                    Conv_BN_NLA(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1),
                    Conv_BN_NLA(in_channels=32, out_channels=32, kernel_size=3, stride=1, padding=1),
                    nn.MaxPool2d(kernel_size=2, stride=2),

                    Conv_BN_NLA(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1),
                    Conv_BN_NLA(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1),
                    nn.MaxPool2d(kernel_size=2, stride=2),

                    Conv_BN_NLA(in_channels=64, out_channels=128, kernel_size=3, stride=1, padding=1),
                    Conv_BN_NLA(in_channels=128, out_channels=128, kernel_size=3, stride=1, padding=1),
                    nn.MaxPool2d(kernel_size=2, stride=2),

                    Conv_BN_NLA(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1),
                    Conv_BN_NLA(in_channels=256, out_channels=256, kernel_size=3, stride=1, padding=1),
                    nn.MaxPool2d(kernel_size=2, stride=2),

                    Conv_BN_NLA(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1),
                    Conv_BN_NLA(in_channels=512, out_channels=512, kernel_size=3, stride=1, padding=1),
                    nn.MaxPool2d(kernel_size=2, stride=2),

                    nn.Dropout2d(),

                    Flatten(),
                    Linear_BN_NLA(in_features=2*2*512, out_features=1024),
                    Linear_BN_NLA(in_features=1024, out_features=1024),
                    nn.Linear(in_features=1024, out_features=3),
            )

    def forward(self, x):
        return self.architecture(x)

# %% [markdown]
# # Loss function definition

# %%
def my_loss(outputs, labels):
    """
    Args:
        outputs - output of network ([batch size, 3])
        labels  - desired labels  ([batch size, 3])
    """

    loss = torch.zeros(1, dtype=torch.float, requires_grad=True).to(device)
    
    """
    Our view of the loss is as the difference between two (batch_size, 3) vectors. Squaring the difference
    makes the loss between an estimation and a label positive, while punishing bigger differences.
    """
    loss = ((labels - outputs)**2).sum(axis=1).mean()

    return loss

# %% [markdown]
# # Get number of trainable parameters (given to you)

# %%
def get_train_params_num(model):
    """
    This fucntion returns the number of trainable parameters of neural network model
    You may want to call it after you create your model to see how many parameteres the model has
    Args:
        model - neural net to examine
    """
    
    #filter given iterable with a function that tests each element in the iterable to be true or not
    model_parameters = filter(lambda p: p.requires_grad == True, model.parameters()) 
    params_num = sum([np.prod(p.size()) for p in model_parameters])
    return params_num

# %% [markdown]
# # Model creation and choice of optimizer

# %%
model = CircleNet().to(device)
print ("Number of model trainable parameters:", get_train_params_num(model))
#----------------------------------------------
#  Choose your optimizer:
#  implementation needed here 
#----------------------------------------------
optimizer = optim.SGD(model.parameters(), lr=2e-03, momentum=0.9, weight_decay=3e-2)
# Out:
# Number of model trainable parameters: 7877721

# %% [markdown]
# # Get an estimate number of operations (given to you)

# %%
def calc_ops(inp_size, net_struct):
    """
    Calculates a rough number of operations for a given network topology
    Args:
        inp_size - (W,H) of input 
        net_struct - list of tuples describing structure of network. 
        
        Example:
         (('conv2d', (3, 8, 3, 1, 0)),  # cin, cout, kernel, stride, pad
          ('conv2d': 83, 8, 3, 1, 0)),
          ('MaxPool2d', (2,2)),         # kernel, stride
          ('fc': (64, 8)),      
          ('fc': (8, 4)))
         
    """
    
    ops = 0
    W, H = inp_size
    for curr_item in net_struct:
        if curr_item[0] == 'conv2d':
            cin = curr_item[1][0]
            cout = curr_item[1][1]
            kernel = curr_item[1][2]
            stride = curr_item[1][3]
            pad = curr_item[1][4]
            W = (W +2*pad - kernel)/stride + 1
            H = (H +2*pad - kernel)/stride + 1
            curr_ops = (W*H*cin*cout*kernel*kernel)/stride
            ops += curr_ops
            print (curr_item, ":",  "{:,}".format(int(curr_ops)))
        elif curr_item[0] == 'MaxPool2d':
            kernel = curr_item[1][0]
            stride = curr_item[1][1]
            W = (W - kernel)/stride + 1
            H = (H - kernel)/stride + 1
        else:
            curr_ops = curr_item[1][0] * curr_item[1][1]
            ops += curr_ops
            print (curr_item, ":",  "{:,}".format(int(curr_ops)))
            
    return int(ops)

# %% [markdown]
# # Check rough number of ops for network (for your convenience)

# %%
inp_size = (128,128)

# place your network ropology in example_net below to obtain an estimated number of operations for your network
example_net = (('conv2d', (3, 3, 3, 1, 1)),
               ('MaxPool2d', (2,2)),
               ('conv2d', (3, 3, 3, 1, 1)),
               ('MaxPool2d', (2,2)),
               ('fc', (2883, 4)))


              
ops = calc_ops(inp_size, example_net)
print()
print("Total ops: {:,}".format(ops))
# Out:
# ('conv2d', (3, 3, 3, 1, 1)) : 1,327,104
# ('conv2d', (3, 3, 3, 1, 1)) : 331,776
# ('fc', (2883, 4)) : 11,532
#
# Total ops: 1,670,412

# %% [markdown]
# # View images, target circle labels and  network outputs (given to you)

# %%
"""
View first image of a given number of batches assuming that model has been created. 
Currently, lines assuming model has been creatd, are commented out. Without a model, 
you can view target labels and the corresponding images.
This is given to you so that you may see how loaders and model can be used. 
"""

loader = train_loader # choose from which loader to show images
bacthes_to_show = 2
with torch.no_grad():
    for i, data in enumerate(loader, 0): #0 means that counting starts at zero
        inputs = (data['image']).to(device)   # has shape (batch_size, 3, 128, 128)
        labels = (data['labels']).to(device)  # has shape (batch_size, 3)
        img_fnames = data['fname']            # list of length batch_size
        
        #outputs = model(inputs.float())
        img = Image.open(img_fnames[0])
        
        print ("showing image: ", img_fnames[0])
        
        labels_str = [ float(("{0:.2f}".format(x))) for x in labels[0]]#labels_np_arr]
        
        #outputs_np_arr = outputs[0] # using ".numpy()" to convert tensor to numpy array
        #outputs_str = [ float(("{0:.2f}".format(x))) for x in outputs_np_arr]
        print("Target labels :", labels_str )
        #print("network coeffs:", outputs_str)
        print()
        #img.show()
        
        if (i+1) == bacthes_to_show:
            break
# Out:
# showing image:  ./train//images/0452.png
# Target labels : [0.5, 0.48, 0.43]
#
# showing image:  ./train//images/0709.png
# Target labels : [0.26, 0.57, 0.18]

# %% [markdown]
# # Validate model function

# %%
def validate_model(model, loader):
    """
    This function parses a given loader and returns the avergae (per image) loss
    (as defined by "my_loss") of the entire dataset associated with the given loader.

    Args:
        model  - neural network to examine
        loader - where input data comes from (train, validation, or test)

    returns:
        average loss per image in variable named "avg_loss"
    """

    model.eval()  # eval mode (batchnorm uses moving mean/variance instead of mini-batch mean/variance)
    # (dropout is set to zero)

    loss = 0
    num_samples = 0
    with torch.no_grad():
        for d in loader:
            inputs = d['image'].to(device=device, dtype=torch.float)
            labels = d['labels'].to(device=device, dtype=torch.float)
            outputs = model(inputs)
            
            batch_size = inputs.size(0)
            
            # multiply by batch_size because my_loss is an average over it
            loss = loss + my_loss(outputs, labels) * batch_size  

    avg_loss = (loss / len(loader.dataset)).item()

    model.train()  # back to default
    return avg_loss

# %% [markdown]
# # train model function

# %%
def reset(m):
    if hasattr(m, 'reset_parameters'):
        m.reset_parameters()

def adjust_lr(optimizer, factor):  
    for i, g in enumerate(optimizer.param_groups):
        old_lr = g['lr']
        new_lr = old_lr * factor
        g['lr'] = new_lr

def make_epoch_training_step(model, optimizer, train_loader):
    for t, d in enumerate(train_loader):
        images = d['image'].to(device=device, dtype=torch.float)
        labels = d['labels'].to(device=device, dtype=torch.float)
        outputs = model(images)
        loss = my_loss(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

# %%
import copy  

def train_model(model,
                optimizer,
                train_loader,
                validation_loader,
                train_losses,
                validation_losses,
                print_every=5,
                epochs=1):
    """
    Trains a neural network.
    Args:
        model               - model to be trained
        optimizer           - optimizer used for training
        train_loader        - loader from which data for training comes
        validation_loader   - loader from which data for validation comes (maybe at the end, you use test_loader)
        train_losses        - adding train loss value to this list for future analysis
        validation_losses   - adding validation loss value to this list for future analysis
        print_every         - print the average validation loss every print_every epochs
        epochs              - number of runs over the entire data set
    """
    
    best_model_state = None
    best_avg_val_loss = 1000

    for epoch in range(1, epochs + 1):
        make_epoch_training_step(model, optimizer, train_loader)

        avg_train_loss = validate_model(model, train_loader)
        avg_validation_loss = validate_model(model, validation_loader)
        train_losses.append(avg_train_loss)
        validation_losses.append(avg_validation_loss)

        if epoch % print_every == 0:
            print(f'epoch {epoch} / {epochs}: avg_val_loss = {avg_validation_loss : .6}')
            
        if math.isnan(avg_validation_loss):
            print("GRADIENT EXPLODED")
            return    
        
        # If a new best model state was reached - save it.
        if avg_validation_loss < best_avg_val_loss:
            best_avg_val_loss = avg_validation_loss
            best_model_state = copy.deepcopy(model)

    # Reload the best state the model has reached
    model.load_state_dict(best_model_state.state_dict())
    final_avg_val_loss = validate_model(best_model_state, validation_loader)
    
    print()
    print(f'Best model state average validatin loss: {final_avg_val_loss}')

# %% [markdown]
# # Actual train (given to you)

# %%
# Using two lists (train_losses, validation_losses) containing history of losses 
# (i.e., loss for each training epoch) for train and validation sets. 
# If thess are not defined, we define them. Otherwise, the function train_model
# updates these two lists (by adding loss values when it is called for further training) 
# in order to be able to visualize train and validation losses


if not 'train_losses' in vars():
    train_losses = []
if not 'validation_losses' in vars():
    validation_losses = []


model = CircleNet().to(device)
optimizer = optim.SGD(model.parameters(), lr=2e-03, momentum=0.9, weight_decay=3e-2)

train_model(model, 
            optimizer,
            train_loader, 
            validation_loader, 
            train_losses, 
            validation_losses,
            print_every=1,
            epochs=1000)
# Out:
# epoch 1 / 1000: avg_val_loss =  0.228529
# epoch 2 / 1000: avg_val_loss =  0.148921
# epoch 3 / 1000: avg_val_loss =  0.105767
# epoch 4 / 1000: avg_val_loss =  0.0997741
# epoch 5 / 1000: avg_val_loss =  0.0677653
# epoch 6 / 1000: avg_val_loss =  0.049543
# epoch 7 / 1000: avg_val_loss =  0.0397347
# epoch 8 / 1000: avg_val_loss =  0.0326345
# epoch 9 / 1000: avg_val_loss =  0.0312528
# epoch 10 / 1000: avg_val_loss =  0.0241613
# epoch 11 / 1000: avg_val_loss =  0.0287521
# epoch 12 / 1000: avg_val_loss =  0.0223091
# epoch 13 / 1000: avg_val_loss =  0.0200982
# epoch 14 / 1000: avg_val_loss =  0.0197395
# epoch 15 / 1000: avg_val_loss =  0.0198234
# epoch 16 / 1000: avg_val_loss =  0.0150891
# epoch 17 / 1000: avg_val_loss =  0.0170599
# epoch 18 / 1000: avg_val_loss =  0.0163516
# epoch 19 / 1000: avg_val_loss =  0.0153564
# epoch 20 / 1000: avg_val_loss =  0.0139621
# epoch 21 / 1000: avg_val_loss =  0.0122617
# epoch 22 / 1000: avg_val_loss =  0.0126383
# epoch 23 / 1000: avg_val_loss =  0.0160791
# epoch 24 / 1000: avg_val_loss =  0.012985
# epoch 25 / 1000: avg_val_loss =  0.011957
# epoch 26 / 1000: avg_val_loss =  0.0120216
# epoch 27 / 1000: avg_val_loss =  0.0117567
# epoch 28 / 1000: avg_val_loss =  0.0138405
# epoch 29 / 1000: avg_val_loss =  0.018483
# epoch 30 / 1000: avg_val_loss =  0.0136269
# epoch 31 / 1000: avg_val_loss =  0.0119827
# epoch 32 / 1000: avg_val_loss =  0.011161
# epoch 33 / 1000: avg_val_loss =  0.00941934
# epoch 34 / 1000: avg_val_loss =  0.0107627
# epoch 35 / 1000: avg_val_loss =  0.0138982
# epoch 36 / 1000: avg_val_loss =  0.0123371
# epoch 37 / 1000: avg_val_loss =  0.0134322
# epoch 38 / 1000: avg_val_loss =  0.0124133
# epoch 39 / 1000: avg_val_loss =  0.011958
# epoch 40 / 1000: avg_val_loss =  0.0121994
# epoch 41 / 1000: avg_val_loss =  0.011311
# epoch 42 / 1000: avg_val_loss =  0.00948866
# epoch 43 / 1000: avg_val_loss =  0.0104019
# epoch 44 / 1000: avg_val_loss =  0.0115184
# epoch 45 / 1000: avg_val_loss =  0.0105427
# epoch 46 / 1000: avg_val_loss =  0.0103398
# epoch 47 / 1000: avg_val_loss =  0.00904799
# epoch 48 / 1000: avg_val_loss =  0.00822829
# epoch 49 / 1000: avg_val_loss =  0.00894297
# epoch 50 / 1000: avg_val_loss =  0.00863782
# epoch 51 / 1000: avg_val_loss =  0.00928574
# epoch 52 / 1000: avg_val_loss =  0.0092578
# epoch 53 / 1000: avg_val_loss =  0.00901781
# epoch 54 / 1000: avg_val_loss =  0.0109279
# epoch 55 / 1000: avg_val_loss =  0.0112353
# epoch 56 / 1000: avg_val_loss =  0.00922181
# epoch 57 / 1000: avg_val_loss =  0.00897951
# epoch 58 / 1000: avg_val_loss =  0.00798389
# epoch 59 / 1000: avg_val_loss =  0.00849516
# epoch 60 / 1000: avg_val_loss =  0.00880779
# epoch 61 / 1000: avg_val_loss =  0.00765801
# epoch 62 / 1000: avg_val_loss =  0.00794898
# epoch 63 / 1000: avg_val_loss =  0.00954533
# epoch 64 / 1000: avg_val_loss =  0.00751129
# epoch 65 / 1000: avg_val_loss =  0.00764828
# epoch 66 / 1000: avg_val_loss =  0.00747407
# epoch 67 / 1000: avg_val_loss =  0.00750161
# epoch 68 / 1000: avg_val_loss =  0.00766074
# epoch 69 / 1000: avg_val_loss =  0.00984381
# epoch 70 / 1000: avg_val_loss =  0.0116508
# epoch 71 / 1000: avg_val_loss =  0.00952225
# epoch 72 / 1000: avg_val_loss =  0.00867303
# epoch 73 / 1000: avg_val_loss =  0.00765322
# epoch 74 / 1000: avg_val_loss =  0.00686877
# epoch 75 / 1000: avg_val_loss =  0.00758149
# epoch 76 / 1000: avg_val_loss =  0.0077916
# epoch 77 / 1000: avg_val_loss =  0.00842742
# epoch 78 / 1000: avg_val_loss =  0.00739868
# epoch 79 / 1000: avg_val_loss =  0.00913458
# epoch 80 / 1000: avg_val_loss =  0.00781141
# epoch 81 / 1000: avg_val_loss =  0.00715905
# epoch 82 / 1000: avg_val_loss =  0.00767832
# epoch 83 / 1000: avg_val_loss =  0.00768539
# epoch 84 / 1000: avg_val_loss =  0.00621947
# epoch 85 / 1000: avg_val_loss =  0.00654965
# epoch 86 / 1000: avg_val_loss =  0.00677132
# epoch 87 / 1000: avg_val_loss =  0.010411
# epoch 88 / 1000: avg_val_loss =  0.0096094
# epoch 89 / 1000: avg_val_loss =  0.00671663
# epoch 90 / 1000: avg_val_loss =  0.00789326
# epoch 91 / 1000: avg_val_loss =  0.00800216
# epoch 92 / 1000: avg_val_loss =  0.00764998
# epoch 93 / 1000: avg_val_loss =  0.00674983
# epoch 94 / 1000: avg_val_loss =  0.00688014
# epoch 95 / 1000: avg_val_loss =  0.00736821
# epoch 96 / 1000: avg_val_loss =  0.00883179
# epoch 97 / 1000: avg_val_loss =  0.0076718
# epoch 98 / 1000: avg_val_loss =  0.00655982
# epoch 99 / 1000: avg_val_loss =  0.00605593
# epoch 100 / 1000: avg_val_loss =  0.00727701
# epoch 101 / 1000: avg_val_loss =  0.00748181
# epoch 102 / 1000: avg_val_loss =  0.00762653
# epoch 103 / 1000: avg_val_loss =  0.00630504
# epoch 104 / 1000: avg_val_loss =  0.00723697
# epoch 105 / 1000: avg_val_loss =  0.00644479
# epoch 106 / 1000: avg_val_loss =  0.00807297
# epoch 107 / 1000: avg_val_loss =  0.00742884
# epoch 108 / 1000: avg_val_loss =  0.00699836
# epoch 109 / 1000: avg_val_loss =  0.00629885
# epoch 110 / 1000: avg_val_loss =  0.00696787
# epoch 111 / 1000: avg_val_loss =  0.00683851
# epoch 112 / 1000: avg_val_loss =  0.00708702
# epoch 113 / 1000: avg_val_loss =  0.00722343
# epoch 114 / 1000: avg_val_loss =  0.00575015
# epoch 115 / 1000: avg_val_loss =  0.00780615
# epoch 116 / 1000: avg_val_loss =  0.00655265
# epoch 117 / 1000: avg_val_loss =  0.00663724
# epoch 118 / 1000: avg_val_loss =  0.00782928
# epoch 119 / 1000: avg_val_loss =  0.00625107
# epoch 120 / 1000: avg_val_loss =  0.00652028
# epoch 121 / 1000: avg_val_loss =  0.00683408
# epoch 122 / 1000: avg_val_loss =  0.00768219
# epoch 123 / 1000: avg_val_loss =  0.0056817
# epoch 124 / 1000: avg_val_loss =  0.00720723
# epoch 125 / 1000: avg_val_loss =  0.0064663
# epoch 126 / 1000: avg_val_loss =  0.00575205
# epoch 127 / 1000: avg_val_loss =  0.00679014
# epoch 128 / 1000: avg_val_loss =  0.00614785
# epoch 129 / 1000: avg_val_loss =  0.00585318
# epoch 130 / 1000: avg_val_loss =  0.00650964
# epoch 131 / 1000: avg_val_loss =  0.00674416
# epoch 132 / 1000: avg_val_loss =  0.00607397
# epoch 133 / 1000: avg_val_loss =  0.00593686
# epoch 134 / 1000: avg_val_loss =  0.00634723
# epoch 135 / 1000: avg_val_loss =  0.00586841
# epoch 136 / 1000: avg_val_loss =  0.0058068
# epoch 137 / 1000: avg_val_loss =  0.00609616
# epoch 138 / 1000: avg_val_loss =  0.00632204
# epoch 139 / 1000: avg_val_loss =  0.00614274
# epoch 140 / 1000: avg_val_loss =  0.00661551
# epoch 141 / 1000: avg_val_loss =  0.00599738
# epoch 142 / 1000: avg_val_loss =  0.0063724
# epoch 143 / 1000: avg_val_loss =  0.00556579
# epoch 144 / 1000: avg_val_loss =  0.00666414
# epoch 145 / 1000: avg_val_loss =  0.00552733
# epoch 146 / 1000: avg_val_loss =  0.00564916
# epoch 147 / 1000: avg_val_loss =  0.00586603
# epoch 148 / 1000: avg_val_loss =  0.00589231
# epoch 149 / 1000: avg_val_loss =  0.005593
# epoch 150 / 1000: avg_val_loss =  0.00563671
# epoch 151 / 1000: avg_val_loss =  0.00573651
# epoch 152 / 1000: avg_val_loss =  0.00573392
# epoch 153 / 1000: avg_val_loss =  0.00591888
# epoch 154 / 1000: avg_val_loss =  0.00544041
# epoch 155 / 1000: avg_val_loss =  0.00572468
# epoch 156 / 1000: avg_val_loss =  0.0052455
# epoch 157 / 1000: avg_val_loss =  0.0055438
# epoch 158 / 1000: avg_val_loss =  0.00534819
# epoch 159 / 1000: avg_val_loss =  0.00552473
# epoch 160 / 1000: avg_val_loss =  0.00526698
# epoch 161 / 1000: avg_val_loss =  0.00529151
# epoch 162 / 1000: avg_val_loss =  0.00538992
# epoch 163 / 1000: avg_val_loss =  0.00553215
# epoch 164 / 1000: avg_val_loss =  0.0054346
# epoch 165 / 1000: avg_val_loss =  0.00545327
# epoch 166 / 1000: avg_val_loss =  0.00516661
# epoch 167 / 1000: avg_val_loss =  0.00547106
# epoch 168 / 1000: avg_val_loss =  0.00515883
# epoch 169 / 1000: avg_val_loss =  0.005663
# epoch 170 / 1000: avg_val_loss =  0.00511665
# epoch 171 / 1000: avg_val_loss =  0.00535057
# epoch 172 / 1000: avg_val_loss =  0.00523677
# epoch 173 / 1000: avg_val_loss =  0.00532244
# epoch 174 / 1000: avg_val_loss =  0.00526168
# epoch 175 / 1000: avg_val_loss =  0.00513475
# epoch 176 / 1000: avg_val_loss =  0.00536677
# epoch 177 / 1000: avg_val_loss =  0.0051244
# epoch 178 / 1000: avg_val_loss =  0.00507121
# epoch 179 / 1000: avg_val_loss =  0.00503719
# epoch 180 / 1000: avg_val_loss =  0.00510285
# epoch 181 / 1000: avg_val_loss =  0.00511854
# epoch 182 / 1000: avg_val_loss =  0.00506507
# epoch 183 / 1000: avg_val_loss =  0.00500509
# epoch 184 / 1000: avg_val_loss =  0.00537272
# epoch 185 / 1000: avg_val_loss =  0.00493704
# epoch 186 / 1000: avg_val_loss =  0.00527143
# epoch 187 / 1000: avg_val_loss =  0.00504503
# epoch 188 / 1000: avg_val_loss =  0.00502252
# epoch 189 / 1000: avg_val_loss =  0.00524388
# epoch 190 / 1000: avg_val_loss =  0.00507112
# epoch 191 / 1000: avg_val_loss =  0.00470825
# epoch 192 / 1000: avg_val_loss =  0.00507937
# epoch 193 / 1000: avg_val_loss =  0.00498998
# epoch 194 / 1000: avg_val_loss =  0.00488239
# epoch 195 / 1000: avg_val_loss =  0.00506087
# epoch 196 / 1000: avg_val_loss =  0.00479154
# epoch 197 / 1000: avg_val_loss =  0.00517217
# epoch 198 / 1000: avg_val_loss =  0.00489011
# epoch 199 / 1000: avg_val_loss =  0.00487506
# epoch 200 / 1000: avg_val_loss =  0.00479493
# epoch 201 / 1000: avg_val_loss =  0.00476352
# epoch 202 / 1000: avg_val_loss =  0.0050971
# epoch 203 / 1000: avg_val_loss =  0.00465384
# epoch 204 / 1000: avg_val_loss =  0.00496474
# epoch 205 / 1000: avg_val_loss =  0.00495421
# epoch 206 / 1000: avg_val_loss =  0.00487331
# epoch 207 / 1000: avg_val_loss =  0.0050384
# epoch 208 / 1000: avg_val_loss =  0.00457188
# epoch 209 / 1000: avg_val_loss =  0.00478738
# epoch 210 / 1000: avg_val_loss =  0.00464701
# epoch 211 / 1000: avg_val_loss =  0.00485094
# epoch 212 / 1000: avg_val_loss =  0.00461714
# epoch 213 / 1000: avg_val_loss =  0.00463406
# epoch 214 / 1000: avg_val_loss =  0.00468898
# epoch 215 / 1000: avg_val_loss =  0.00475388
# epoch 216 / 1000: avg_val_loss =  0.00479704
# epoch 217 / 1000: avg_val_loss =  0.00479162
# epoch 218 / 1000: avg_val_loss =  0.00448133
# epoch 219 / 1000: avg_val_loss =  0.00456606
# epoch 220 / 1000: avg_val_loss =  0.00455116
# epoch 221 / 1000: avg_val_loss =  0.00441001
# epoch 222 / 1000: avg_val_loss =  0.00450521
# epoch 223 / 1000: avg_val_loss =  0.00460569
# epoch 224 / 1000: avg_val_loss =  0.004409
# epoch 225 / 1000: avg_val_loss =  0.00449642
# epoch 226 / 1000: avg_val_loss =  0.00473732
# epoch 227 / 1000: avg_val_loss =  0.00431727
# epoch 228 / 1000: avg_val_loss =  0.00458661
# epoch 229 / 1000: avg_val_loss =  0.00485078
# epoch 230 / 1000: avg_val_loss =  0.004229
# epoch 231 / 1000: avg_val_loss =  0.00461551
# epoch 232 / 1000: avg_val_loss =  0.00459184
# epoch 233 / 1000: avg_val_loss =  0.00448446
# epoch 234 / 1000: avg_val_loss =  0.0043935
# epoch 235 / 1000: avg_val_loss =  0.00431628
# epoch 236 / 1000: avg_val_loss =  0.00453223
# epoch 237 / 1000: avg_val_loss =  0.00427279
# epoch 238 / 1000: avg_val_loss =  0.00441976
# epoch 239 / 1000: avg_val_loss =  0.00460941
# epoch 240 / 1000: avg_val_loss =  0.00450592
# epoch 241 / 1000: avg_val_loss =  0.00432573
# epoch 242 / 1000: avg_val_loss =  0.00433437
# epoch 243 / 1000: avg_val_loss =  0.00431286
# epoch 244 / 1000: avg_val_loss =  0.00416221
# epoch 245 / 1000: avg_val_loss =  0.00442217
# epoch 246 / 1000: avg_val_loss =  0.00430128
# epoch 247 / 1000: avg_val_loss =  0.00419722
# epoch 248 / 1000: avg_val_loss =  0.00421828
# epoch 249 / 1000: avg_val_loss =  0.00419278
# epoch 250 / 1000: avg_val_loss =  0.00418279
# epoch 251 / 1000: avg_val_loss =  0.00441089
# epoch 252 / 1000: avg_val_loss =  0.00415424
# epoch 253 / 1000: avg_val_loss =  0.00416023
# epoch 254 / 1000: avg_val_loss =  0.00427516
# epoch 255 / 1000: avg_val_loss =  0.00431756
# epoch 256 / 1000: avg_val_loss =  0.0042564
# epoch 257 / 1000: avg_val_loss =  0.00416883
# epoch 258 / 1000: avg_val_loss =  0.0045339
# epoch 259 / 1000: avg_val_loss =  0.00404546
# epoch 260 / 1000: avg_val_loss =  0.0042966
# epoch 261 / 1000: avg_val_loss =  0.00411115
# epoch 262 / 1000: avg_val_loss =  0.00429805
# epoch 263 / 1000: avg_val_loss =  0.00414685
# epoch 264 / 1000: avg_val_loss =  0.00412096
# epoch 265 / 1000: avg_val_loss =  0.00420187
# epoch 266 / 1000: avg_val_loss =  0.00425537
# epoch 267 / 1000: avg_val_loss =  0.00420851
# epoch 268 / 1000: avg_val_loss =  0.00415165
# epoch 269 / 1000: avg_val_loss =  0.0042569
# epoch 270 / 1000: avg_val_loss =  0.00451293
# epoch 271 / 1000: avg_val_loss =  0.00428073
# epoch 272 / 1000: avg_val_loss =  0.00458097
# epoch 273 / 1000: avg_val_loss =  0.0042072
# epoch 274 / 1000: avg_val_loss =  0.00432004
# epoch 275 / 1000: avg_val_loss =  0.00426537
# epoch 276 / 1000: avg_val_loss =  0.00395708
# epoch 277 / 1000: avg_val_loss =  0.00396498
# epoch 278 / 1000: avg_val_loss =  0.00403764
# epoch 279 / 1000: avg_val_loss =  0.00402113
# epoch 280 / 1000: avg_val_loss =  0.00390727
# epoch 281 / 1000: avg_val_loss =  0.00385184
# epoch 282 / 1000: avg_val_loss =  0.00393749
# epoch 283 / 1000: avg_val_loss =  0.00383242
# epoch 284 / 1000: avg_val_loss =  0.00388509
# epoch 285 / 1000: avg_val_loss =  0.00399931
# epoch 286 / 1000: avg_val_loss =  0.00418861
# epoch 287 / 1000: avg_val_loss =  0.00373634
# epoch 288 / 1000: avg_val_loss =  0.0038435
# epoch 289 / 1000: avg_val_loss =  0.00382201
# epoch 290 / 1000: avg_val_loss =  0.00408863
# epoch 291 / 1000: avg_val_loss =  0.00382592
# epoch 292 / 1000: avg_val_loss =  0.00381486
# epoch 293 / 1000: avg_val_loss =  0.00397699
# epoch 294 / 1000: avg_val_loss =  0.00427008
# epoch 295 / 1000: avg_val_loss =  0.00394899
# epoch 296 / 1000: avg_val_loss =  0.00371175
# epoch 297 / 1000: avg_val_loss =  0.00398424
# epoch 298 / 1000: avg_val_loss =  0.00436083
# epoch 299 / 1000: avg_val_loss =  0.00391206
# epoch 300 / 1000: avg_val_loss =  0.00428067
# epoch 301 / 1000: avg_val_loss =  0.00421117
# epoch 302 / 1000: avg_val_loss =  0.00394486
# epoch 303 / 1000: avg_val_loss =  0.00396784
# epoch 304 / 1000: avg_val_loss =  0.00391479
# epoch 305 / 1000: avg_val_loss =  0.0039601
# epoch 306 / 1000: avg_val_loss =  0.00382283
# epoch 307 / 1000: avg_val_loss =  0.0038551
# epoch 308 / 1000: avg_val_loss =  0.00383728
# epoch 309 / 1000: avg_val_loss =  0.00357457
# epoch 310 / 1000: avg_val_loss =  0.00369679
# epoch 311 / 1000: avg_val_loss =  0.0038261
# epoch 312 / 1000: avg_val_loss =  0.00373343
# epoch 313 / 1000: avg_val_loss =  0.00379832
# epoch 314 / 1000: avg_val_loss =  0.00445066
# epoch 315 / 1000: avg_val_loss =  0.00355049
# epoch 316 / 1000: avg_val_loss =  0.00388041
# epoch 317 / 1000: avg_val_loss =  0.00435399
# epoch 318 / 1000: avg_val_loss =  0.00403765
# epoch 319 / 1000: avg_val_loss =  0.003674
# epoch 320 / 1000: avg_val_loss =  0.00385963
# epoch 321 / 1000: avg_val_loss =  0.00399808
# epoch 322 / 1000: avg_val_loss =  0.0037583
# epoch 323 / 1000: avg_val_loss =  0.00397278
# epoch 324 / 1000: avg_val_loss =  0.00381712
# epoch 325 / 1000: avg_val_loss =  0.00374318
# epoch 326 / 1000: avg_val_loss =  0.00359319
# epoch 327 / 1000: avg_val_loss =  0.00350465
# epoch 328 / 1000: avg_val_loss =  0.00346366
# epoch 329 / 1000: avg_val_loss =  0.00406895
# epoch 330 / 1000: avg_val_loss =  0.00394275
# epoch 331 / 1000: avg_val_loss =  0.00372
# epoch 332 / 1000: avg_val_loss =  0.00379798
# epoch 333 / 1000: avg_val_loss =  0.00365091
# epoch 334 / 1000: avg_val_loss =  0.0035968
# epoch 335 / 1000: avg_val_loss =  0.00384321
# epoch 336 / 1000: avg_val_loss =  0.00363116
# epoch 337 / 1000: avg_val_loss =  0.00354813
# epoch 338 / 1000: avg_val_loss =  0.00362377
# epoch 339 / 1000: avg_val_loss =  0.00379458
# epoch 340 / 1000: avg_val_loss =  0.00347833
# epoch 341 / 1000: avg_val_loss =  0.00364705
# epoch 342 / 1000: avg_val_loss =  0.00399468
# epoch 343 / 1000: avg_val_loss =  0.00359903
# epoch 344 / 1000: avg_val_loss =  0.00371056
# epoch 345 / 1000: avg_val_loss =  0.00358048
# epoch 346 / 1000: avg_val_loss =  0.00340642
# epoch 347 / 1000: avg_val_loss =  0.00372714
# epoch 348 / 1000: avg_val_loss =  0.00366414
# epoch 349 / 1000: avg_val_loss =  0.00358916
# epoch 350 / 1000: avg_val_loss =  0.00384159
# epoch 351 / 1000: avg_val_loss =  0.00333077
# epoch 352 / 1000: avg_val_loss =  0.00361119
# epoch 353 / 1000: avg_val_loss =  0.00366754
# epoch 354 / 1000: avg_val_loss =  0.00368452
# epoch 355 / 1000: avg_val_loss =  0.00348757
# epoch 356 / 1000: avg_val_loss =  0.00333817
# epoch 357 / 1000: avg_val_loss =  0.00319859
# epoch 358 / 1000: avg_val_loss =  0.00371239
# epoch 359 / 1000: avg_val_loss =  0.0035372
# epoch 360 / 1000: avg_val_loss =  0.00341472
# epoch 361 / 1000: avg_val_loss =  0.00366527
# epoch 362 / 1000: avg_val_loss =  0.00380116
# epoch 363 / 1000: avg_val_loss =  0.00327988
# epoch 364 / 1000: avg_val_loss =  0.00343737
# epoch 365 / 1000: avg_val_loss =  0.00320044
# epoch 366 / 1000: avg_val_loss =  0.00327407
# epoch 367 / 1000: avg_val_loss =  0.00374299
# epoch 368 / 1000: avg_val_loss =  0.00363124
# epoch 369 / 1000: avg_val_loss =  0.00323093
# epoch 370 / 1000: avg_val_loss =  0.00358562
# epoch 371 / 1000: avg_val_loss =  0.00325285
# epoch 372 / 1000: avg_val_loss =  0.00291953
# epoch 373 / 1000: avg_val_loss =  0.00328396
# epoch 374 / 1000: avg_val_loss =  0.00303273
# epoch 375 / 1000: avg_val_loss =  0.00350638
# epoch 376 / 1000: avg_val_loss =  0.00327221
# epoch 377 / 1000: avg_val_loss =  0.00367319
# epoch 378 / 1000: avg_val_loss =  0.002484
# epoch 379 / 1000: avg_val_loss =  0.00289539
# epoch 380 / 1000: avg_val_loss =  0.00366958
# epoch 381 / 1000: avg_val_loss =  0.00315902
# epoch 382 / 1000: avg_val_loss =  0.00314472
# epoch 383 / 1000: avg_val_loss =  0.00320213
# epoch 384 / 1000: avg_val_loss =  0.00303744
# epoch 385 / 1000: avg_val_loss =  0.00289873
# epoch 386 / 1000: avg_val_loss =  0.00270496
# epoch 387 / 1000: avg_val_loss =  0.00278664
# epoch 388 / 1000: avg_val_loss =  0.00279584
# epoch 389 / 1000: avg_val_loss =  0.0026865
# epoch 390 / 1000: avg_val_loss =  0.00299995
# epoch 391 / 1000: avg_val_loss =  0.00233905
# epoch 392 / 1000: avg_val_loss =  0.00223708
# epoch 393 / 1000: avg_val_loss =  0.00259843
# epoch 394 / 1000: avg_val_loss =  0.00246498
# epoch 395 / 1000: avg_val_loss =  0.00266782
# epoch 396 / 1000: avg_val_loss =  0.0022682
# epoch 397 / 1000: avg_val_loss =  0.00250665
# epoch 398 / 1000: avg_val_loss =  0.00244656
# epoch 399 / 1000: avg_val_loss =  0.00216709
# epoch 400 / 1000: avg_val_loss =  0.00235259
# epoch 401 / 1000: avg_val_loss =  0.00205314
# epoch 402 / 1000: avg_val_loss =  0.00208911
# epoch 403 / 1000: avg_val_loss =  0.00188202
# epoch 404 / 1000: avg_val_loss =  0.00209853
# epoch 405 / 1000: avg_val_loss =  0.00190493
# epoch 406 / 1000: avg_val_loss =  0.00173795
# epoch 407 / 1000: avg_val_loss =  0.00170283
# epoch 408 / 1000: avg_val_loss =  0.0019832
# epoch 409 / 1000: avg_val_loss =  0.00146093
# epoch 410 / 1000: avg_val_loss =  0.00147851
# epoch 411 / 1000: avg_val_loss =  0.00147522
# epoch 412 / 1000: avg_val_loss =  0.00163832
# epoch 413 / 1000: avg_val_loss =  0.00138197
# epoch 414 / 1000: avg_val_loss =  0.00146751
# epoch 415 / 1000: avg_val_loss =  0.00133714
# epoch 416 / 1000: avg_val_loss =  0.00128352
# epoch 417 / 1000: avg_val_loss =  0.00118611
# epoch 418 / 1000: avg_val_loss =  0.0011093
# epoch 419 / 1000: avg_val_loss =  0.00141121
# epoch 420 / 1000: avg_val_loss =  0.000978605
# epoch 421 / 1000: avg_val_loss =  0.00121957
# epoch 422 / 1000: avg_val_loss =  0.00125927
# epoch 423 / 1000: avg_val_loss =  0.000949677
# epoch 424 / 1000: avg_val_loss =  0.00132877
# epoch 425 / 1000: avg_val_loss =  0.000908895
# epoch 426 / 1000: avg_val_loss =  0.000934316
# epoch 427 / 1000: avg_val_loss =  0.000962611
# epoch 428 / 1000: avg_val_loss =  0.00120792
# epoch 429 / 1000: avg_val_loss =  0.00110069
# epoch 430 / 1000: avg_val_loss =  0.00100345
# epoch 431 / 1000: avg_val_loss =  0.000941232
# epoch 432 / 1000: avg_val_loss =  0.000983165
# epoch 433 / 1000: avg_val_loss =  0.000879232
# epoch 434 / 1000: avg_val_loss =  0.000987902
# epoch 435 / 1000: avg_val_loss =  0.00112754
# epoch 436 / 1000: avg_val_loss =  0.000923935
# epoch 437 / 1000: avg_val_loss =  0.000953908
# epoch 438 / 1000: avg_val_loss =  0.000972214
# epoch 439 / 1000: avg_val_loss =  0.000888732
# epoch 440 / 1000: avg_val_loss =  0.00102812
# epoch 441 / 1000: avg_val_loss =  0.00102554
# epoch 442 / 1000: avg_val_loss =  0.00104964
# epoch 443 / 1000: avg_val_loss =  0.000920432
# epoch 444 / 1000: avg_val_loss =  0.000937825
# epoch 445 / 1000: avg_val_loss =  0.000943
# epoch 446 / 1000: avg_val_loss =  0.00101504
# epoch 447 / 1000: avg_val_loss =  0.000985494
# epoch 448 / 1000: avg_val_loss =  0.000941688
# epoch 449 / 1000: avg_val_loss =  0.000944939
# epoch 450 / 1000: avg_val_loss =  0.0010529
# epoch 451 / 1000: avg_val_loss =  0.00100073
# epoch 452 / 1000: avg_val_loss =  0.000932615
# epoch 453 / 1000: avg_val_loss =  0.00103825
# epoch 454 / 1000: avg_val_loss =  0.000967977
# epoch 455 / 1000: avg_val_loss =  0.00101294
# epoch 456 / 1000: avg_val_loss =  0.00101622
# epoch 457 / 1000: avg_val_loss =  0.00106862
# epoch 458 / 1000: avg_val_loss =  0.00104004
# epoch 459 / 1000: avg_val_loss =  0.00103468
# epoch 460 / 1000: avg_val_loss =  0.00105147
# epoch 461 / 1000: avg_val_loss =  0.00108139
# epoch 462 / 1000: avg_val_loss =  0.00108522
# epoch 463 / 1000: avg_val_loss =  0.00112298
# epoch 464 / 1000: avg_val_loss =  0.00111185
# epoch 465 / 1000: avg_val_loss =  0.00107724
# epoch 466 / 1000: avg_val_loss =  0.00113043
# epoch 467 / 1000: avg_val_loss =  0.00115524
# epoch 468 / 1000: avg_val_loss =  0.00110694
# epoch 469 / 1000: avg_val_loss =  0.00114254
# epoch 470 / 1000: avg_val_loss =  0.00114958
# epoch 471 / 1000: avg_val_loss =  0.00118355
# epoch 472 / 1000: avg_val_loss =  0.00129695
# epoch 473 / 1000: avg_val_loss =  0.00119106
# epoch 474 / 1000: avg_val_loss =  0.00117383
# epoch 475 / 1000: avg_val_loss =  0.0012431
# epoch 476 / 1000: avg_val_loss =  0.00115592
# epoch 477 / 1000: avg_val_loss =  0.00124186
# epoch 478 / 1000: avg_val_loss =  0.0013697
# epoch 479 / 1000: avg_val_loss =  0.00124751
# epoch 480 / 1000: avg_val_loss =  0.00129041
# epoch 481 / 1000: avg_val_loss =  0.00129252
# epoch 482 / 1000: avg_val_loss =  0.00131278
# epoch 483 / 1000: avg_val_loss =  0.00132786
# epoch 484 / 1000: avg_val_loss =  0.0012808
# epoch 485 / 1000: avg_val_loss =  0.00130669
# epoch 486 / 1000: avg_val_loss =  0.00139948
# epoch 487 / 1000: avg_val_loss =  0.001318
# epoch 488 / 1000: avg_val_loss =  0.00132153
# epoch 489 / 1000: avg_val_loss =  0.00153007
# epoch 490 / 1000: avg_val_loss =  0.00145595
# epoch 491 / 1000: avg_val_loss =  0.0015374
# epoch 492 / 1000: avg_val_loss =  0.00154085
# epoch 493 / 1000: avg_val_loss =  0.00148191
# epoch 494 / 1000: avg_val_loss =  0.00151512
# epoch 495 / 1000: avg_val_loss =  0.00148527
# epoch 496 / 1000: avg_val_loss =  0.00158607
# epoch 497 / 1000: avg_val_loss =  0.00158738
# epoch 498 / 1000: avg_val_loss =  0.00147239
# epoch 499 / 1000: avg_val_loss =  0.00160541
# epoch 500 / 1000: avg_val_loss =  0.00160021
# epoch 501 / 1000: avg_val_loss =  0.00154543
# epoch 502 / 1000: avg_val_loss =  0.00153288
# epoch 503 / 1000: avg_val_loss =  0.00168512
# epoch 504 / 1000: avg_val_loss =  0.0016522
# epoch 505 / 1000: avg_val_loss =  0.00160382
# epoch 506 / 1000: avg_val_loss =  0.00166435
# epoch 507 / 1000: avg_val_loss =  0.00161423
# epoch 508 / 1000: avg_val_loss =  0.00165878
# epoch 509 / 1000: avg_val_loss =  0.00180446
# epoch 510 / 1000: avg_val_loss =  0.00168206
# epoch 511 / 1000: avg_val_loss =  0.00170683
# epoch 512 / 1000: avg_val_loss =  0.00178008
# epoch 513 / 1000: avg_val_loss =  0.0018102
# epoch 514 / 1000: avg_val_loss =  0.00179484
# epoch 515 / 1000: avg_val_loss =  0.0019038
# epoch 516 / 1000: avg_val_loss =  0.00184571
# epoch 517 / 1000: avg_val_loss =  0.00187726
# epoch 518 / 1000: avg_val_loss =  0.00194478
# epoch 519 / 1000: avg_val_loss =  0.0018521
# epoch 520 / 1000: avg_val_loss =  0.00198296
# epoch 521 / 1000: avg_val_loss =  0.0019272
# epoch 522 / 1000: avg_val_loss =  0.00187808
# epoch 523 / 1000: avg_val_loss =  0.00196158
# epoch 524 / 1000: avg_val_loss =  0.00189199
# epoch 525 / 1000: avg_val_loss =  0.00193444
# epoch 526 / 1000: avg_val_loss =  0.00208373
# epoch 527 / 1000: avg_val_loss =  0.00204133
# epoch 528 / 1000: avg_val_loss =  0.00196913
# epoch 529 / 1000: avg_val_loss =  0.00197873
# epoch 530 / 1000: avg_val_loss =  0.00202612
# epoch 531 / 1000: avg_val_loss =  0.00212687
# epoch 532 / 1000: avg_val_loss =  0.0021227
# epoch 533 / 1000: avg_val_loss =  0.00218956
# epoch 534 / 1000: avg_val_loss =  0.00228727
# epoch 535 / 1000: avg_val_loss =  0.00212492
# epoch 536 / 1000: avg_val_loss =  0.00217262
# epoch 537 / 1000: avg_val_loss =  0.00220181
# epoch 538 / 1000: avg_val_loss =  0.00221077
# epoch 539 / 1000: avg_val_loss =  0.00243983
# epoch 540 / 1000: avg_val_loss =  0.00219024
# epoch 541 / 1000: avg_val_loss =  0.00225907
# epoch 542 / 1000: avg_val_loss =  0.00228134
# epoch 543 / 1000: avg_val_loss =  0.00221337
# epoch 544 / 1000: avg_val_loss =  0.00225891
# epoch 545 / 1000: avg_val_loss =  0.00227133
# epoch 546 / 1000: avg_val_loss =  0.00245626
# epoch 547 / 1000: avg_val_loss =  0.00238059
# epoch 548 / 1000: avg_val_loss =  0.00234678
# epoch 549 / 1000: avg_val_loss =  0.0025087
# epoch 550 / 1000: avg_val_loss =  0.00243903
# epoch 551 / 1000: avg_val_loss =  0.00237071
# epoch 552 / 1000: avg_val_loss =  0.00240085
# epoch 553 / 1000: avg_val_loss =  0.00247252
# epoch 554 / 1000: avg_val_loss =  0.00254931
# epoch 555 / 1000: avg_val_loss =  0.00254524
# epoch 556 / 1000: avg_val_loss =  0.00259129
# epoch 557 / 1000: avg_val_loss =  0.00259881
# epoch 558 / 1000: avg_val_loss =  0.00261845
# epoch 559 / 1000: avg_val_loss =  0.0024765
# epoch 560 / 1000: avg_val_loss =  0.00265958
# epoch 561 / 1000: avg_val_loss =  0.00266479
# epoch 562 / 1000: avg_val_loss =  0.00260661
# epoch 563 / 1000: avg_val_loss =  0.00261653
# epoch 564 / 1000: avg_val_loss =  0.00262161
# epoch 565 / 1000: avg_val_loss =  0.00274278
# epoch 566 / 1000: avg_val_loss =  0.0026708
# epoch 567 / 1000: avg_val_loss =  0.00271437
# epoch 568 / 1000: avg_val_loss =  0.00284278
# epoch 569 / 1000: avg_val_loss =  0.00276111
# epoch 570 / 1000: avg_val_loss =  0.00279394
# epoch 571 / 1000: avg_val_loss =  0.00277953
# epoch 572 / 1000: avg_val_loss =  0.00283268
# epoch 573 / 1000: avg_val_loss =  0.00280685
# epoch 574 / 1000: avg_val_loss =  0.00284407
# epoch 575 / 1000: avg_val_loss =  0.00286278
# epoch 576 / 1000: avg_val_loss =  0.00286506
# epoch 577 / 1000: avg_val_loss =  0.00282324
# epoch 578 / 1000: avg_val_loss =  0.00283551
# epoch 579 / 1000: avg_val_loss =  0.00284415
# epoch 580 / 1000: avg_val_loss =  0.00299681
# epoch 581 / 1000: avg_val_loss =  0.0029792
# epoch 582 / 1000: avg_val_loss =  0.00285109
# epoch 583 / 1000: avg_val_loss =  0.00279317
# epoch 584 / 1000: avg_val_loss =  0.00291957
# epoch 585 / 1000: avg_val_loss =  0.00300261
# epoch 586 / 1000: avg_val_loss =  0.00292127
# epoch 587 / 1000: avg_val_loss =  0.00305504
# epoch 588 / 1000: avg_val_loss =  0.00312286
# epoch 589 / 1000: avg_val_loss =  0.00298371
# epoch 590 / 1000: avg_val_loss =  0.00295052
# epoch 591 / 1000: avg_val_loss =  0.00302293
# epoch 592 / 1000: avg_val_loss =  0.00296479
# epoch 593 / 1000: avg_val_loss =  0.00311395
# epoch 594 / 1000: avg_val_loss =  0.00318615
# epoch 595 / 1000: avg_val_loss =  0.00310587
# epoch 596 / 1000: avg_val_loss =  0.00310194
# epoch 597 / 1000: avg_val_loss =  0.00325886
# epoch 598 / 1000: avg_val_loss =  0.00320582
# epoch 599 / 1000: avg_val_loss =  0.00315577
# epoch 600 / 1000: avg_val_loss =  0.00309686
# epoch 601 / 1000: avg_val_loss =  0.00308954
# epoch 602 / 1000: avg_val_loss =  0.00322003
# epoch 603 / 1000: avg_val_loss =  0.0032053
# epoch 604 / 1000: avg_val_loss =  0.00324617
# epoch 605 / 1000: avg_val_loss =  0.00327562
# epoch 606 / 1000: avg_val_loss =  0.00322824
# epoch 607 / 1000: avg_val_loss =  0.00333946
# epoch 608 / 1000: avg_val_loss =  0.00319244
# epoch 609 / 1000: avg_val_loss =  0.0031951
# epoch 610 / 1000: avg_val_loss =  0.0032309
# epoch 611 / 1000: avg_val_loss =  0.00329022
# epoch 612 / 1000: avg_val_loss =  0.00335115
# epoch 613 / 1000: avg_val_loss =  0.00335324
# epoch 614 / 1000: avg_val_loss =  0.00332982
# epoch 615 / 1000: avg_val_loss =  0.00329258
# epoch 616 / 1000: avg_val_loss =  0.00329937
# epoch 617 / 1000: avg_val_loss =  0.0033528
# epoch 618 / 1000: avg_val_loss =  0.00326354
# epoch 619 / 1000: avg_val_loss =  0.00347921
# epoch 620 / 1000: avg_val_loss =  0.00338175
# epoch 621 / 1000: avg_val_loss =  0.0033693
# epoch 622 / 1000: avg_val_loss =  0.00332926
# epoch 623 / 1000: avg_val_loss =  0.0033983
# epoch 624 / 1000: avg_val_loss =  0.00353733
# epoch 625 / 1000: avg_val_loss =  0.00343554
# epoch 626 / 1000: avg_val_loss =  0.00340122
# epoch 627 / 1000: avg_val_loss =  0.00336138
# epoch 628 / 1000: avg_val_loss =  0.00337777
# epoch 629 / 1000: avg_val_loss =  0.00363959
# epoch 630 / 1000: avg_val_loss =  0.00344187
# epoch 631 / 1000: avg_val_loss =  0.00341525
# epoch 632 / 1000: avg_val_loss =  0.00347825
# epoch 633 / 1000: avg_val_loss =  0.00345206
# epoch 634 / 1000: avg_val_loss =  0.00357156
# epoch 635 / 1000: avg_val_loss =  0.0035943
# epoch 636 / 1000: avg_val_loss =  0.0035395
# epoch 637 / 1000: avg_val_loss =  0.00353751
# epoch 638 / 1000: avg_val_loss =  0.00364317
# epoch 639 / 1000: avg_val_loss =  0.00372157
# epoch 640 / 1000: avg_val_loss =  0.00363363
# epoch 641 / 1000: avg_val_loss =  0.00357691
# epoch 642 / 1000: avg_val_loss =  0.00364102
# epoch 643 / 1000: avg_val_loss =  0.00359046
# epoch 644 / 1000: avg_val_loss =  0.0036534
# epoch 645 / 1000: avg_val_loss =  0.00369086
# epoch 646 / 1000: avg_val_loss =  0.00365059
# epoch 647 / 1000: avg_val_loss =  0.0037088
# epoch 648 / 1000: avg_val_loss =  0.00371484
# epoch 649 / 1000: avg_val_loss =  0.00358154
# epoch 650 / 1000: avg_val_loss =  0.00374705
# epoch 651 / 1000: avg_val_loss =  0.00366465
# epoch 652 / 1000: avg_val_loss =  0.0036722
# epoch 653 / 1000: avg_val_loss =  0.00380612
# epoch 654 / 1000: avg_val_loss =  0.00383854
# epoch 655 / 1000: avg_val_loss =  0.00367414
# epoch 656 / 1000: avg_val_loss =  0.00381687
# epoch 657 / 1000: avg_val_loss =  0.00376006
# epoch 658 / 1000: avg_val_loss =  0.0037736
# epoch 659 / 1000: avg_val_loss =  0.00378891
# epoch 660 / 1000: avg_val_loss =  0.00384004
# epoch 661 / 1000: avg_val_loss =  0.00374867
# epoch 662 / 1000: avg_val_loss =  0.00374864
# epoch 663 / 1000: avg_val_loss =  0.00373494
# epoch 664 / 1000: avg_val_loss =  0.00378838
# epoch 665 / 1000: avg_val_loss =  0.00384388
# epoch 666 / 1000: avg_val_loss =  0.00397416
# epoch 667 / 1000: avg_val_loss =  0.00384
# epoch 668 / 1000: avg_val_loss =  0.0038968
# epoch 669 / 1000: avg_val_loss =  0.00392289
# epoch 670 / 1000: avg_val_loss =  0.00395262
# epoch 671 / 1000: avg_val_loss =  0.00385653
# epoch 672 / 1000: avg_val_loss =  0.00396756
# epoch 673 / 1000: avg_val_loss =  0.00389225
# epoch 674 / 1000: avg_val_loss =  0.00399068
# epoch 675 / 1000: avg_val_loss =  0.00395213
# epoch 676 / 1000: avg_val_loss =  0.00389919
# epoch 677 / 1000: avg_val_loss =  0.00387391
# epoch 678 / 1000: avg_val_loss =  0.00393358
# epoch 679 / 1000: avg_val_loss =  0.00394668
# epoch 680 / 1000: avg_val_loss =  0.00386008
# epoch 681 / 1000: avg_val_loss =  0.0039895
# epoch 682 / 1000: avg_val_loss =  0.00411432
# epoch 683 / 1000: avg_val_loss =  0.00394158
# epoch 684 / 1000: avg_val_loss =  0.00401562
# epoch 685 / 1000: avg_val_loss =  0.00396918
# epoch 686 / 1000: avg_val_loss =  0.00399371
# epoch 687 / 1000: avg_val_loss =  0.00409328
# epoch 688 / 1000: avg_val_loss =  0.00415044
# epoch 689 / 1000: avg_val_loss =  0.00409686
# epoch 690 / 1000: avg_val_loss =  0.00403577
# epoch 691 / 1000: avg_val_loss =  0.00397184
# epoch 692 / 1000: avg_val_loss =  0.00404644
# epoch 693 / 1000: avg_val_loss =  0.00405582
# epoch 694 / 1000: avg_val_loss =  0.00402359
# epoch 695 / 1000: avg_val_loss =  0.00416258
# epoch 696 / 1000: avg_val_loss =  0.00427325
# epoch 697 / 1000: avg_val_loss =  0.00399717
# epoch 698 / 1000: avg_val_loss =  0.00427037
# epoch 699 / 1000: avg_val_loss =  0.00406731
# epoch 700 / 1000: avg_val_loss =  0.00412779
# epoch 701 / 1000: avg_val_loss =  0.00415981
# epoch 702 / 1000: avg_val_loss =  0.00404367
# epoch 703 / 1000: avg_val_loss =  0.00417052
# epoch 704 / 1000: avg_val_loss =  0.0041209
# epoch 705 / 1000: avg_val_loss =  0.00415799
# epoch 706 / 1000: avg_val_loss =  0.0042015
# epoch 707 / 1000: avg_val_loss =  0.00409964
# epoch 708 / 1000: avg_val_loss =  0.00416487
# epoch 709 / 1000: avg_val_loss =  0.00408144
# epoch 710 / 1000: avg_val_loss =  0.00420916
# epoch 711 / 1000: avg_val_loss =  0.00418215
# epoch 712 / 1000: avg_val_loss =  0.00433978
# epoch 713 / 1000: avg_val_loss =  0.00415931
# epoch 714 / 1000: avg_val_loss =  0.00419672
# epoch 715 / 1000: avg_val_loss =  0.00428098
# epoch 716 / 1000: avg_val_loss =  0.00415492
# epoch 717 / 1000: avg_val_loss =  0.00430004
# epoch 718 / 1000: avg_val_loss =  0.00421364
# epoch 719 / 1000: avg_val_loss =  0.0041519
# epoch 720 / 1000: avg_val_loss =  0.00431397
# epoch 721 / 1000: avg_val_loss =  0.0041585
# epoch 722 / 1000: avg_val_loss =  0.0041781
# epoch 723 / 1000: avg_val_loss =  0.00420043
# epoch 724 / 1000: avg_val_loss =  0.00426707
# epoch 725 / 1000: avg_val_loss =  0.004175
# epoch 726 / 1000: avg_val_loss =  0.00437034
# epoch 727 / 1000: avg_val_loss =  0.00412559
# epoch 728 / 1000: avg_val_loss =  0.00432422
# epoch 729 / 1000: avg_val_loss =  0.00432333
# epoch 730 / 1000: avg_val_loss =  0.00424463
# epoch 731 / 1000: avg_val_loss =  0.00419014
# epoch 732 / 1000: avg_val_loss =  0.00418525
# epoch 733 / 1000: avg_val_loss =  0.00438052
# epoch 734 / 1000: avg_val_loss =  0.00421608
# epoch 735 / 1000: avg_val_loss =  0.00411397
# epoch 736 / 1000: avg_val_loss =  0.00427685
# epoch 737 / 1000: avg_val_loss =  0.00427903
# epoch 738 / 1000: avg_val_loss =  0.00431322
# epoch 739 / 1000: avg_val_loss =  0.00430533
# epoch 740 / 1000: avg_val_loss =  0.00423457
# epoch 741 / 1000: avg_val_loss =  0.0043063
# epoch 742 / 1000: avg_val_loss =  0.00439107
# epoch 743 / 1000: avg_val_loss =  0.00422013
# epoch 744 / 1000: avg_val_loss =  0.00436104
# epoch 745 / 1000: avg_val_loss =  0.00433912
# epoch 746 / 1000: avg_val_loss =  0.00442243
# epoch 747 / 1000: avg_val_loss =  0.0042607
# epoch 748 / 1000: avg_val_loss =  0.00431086
# epoch 749 / 1000: avg_val_loss =  0.00421092
# epoch 750 / 1000: avg_val_loss =  0.00421602
# epoch 751 / 1000: avg_val_loss =  0.00437576
# epoch 752 / 1000: avg_val_loss =  0.00431787
# epoch 753 / 1000: avg_val_loss =  0.00436584
# epoch 754 / 1000: avg_val_loss =  0.00445715
# epoch 755 / 1000: avg_val_loss =  0.00415991
# epoch 756 / 1000: avg_val_loss =  0.00453024
# epoch 757 / 1000: avg_val_loss =  0.00435396
# epoch 758 / 1000: avg_val_loss =  0.00436141
# epoch 759 / 1000: avg_val_loss =  0.00435809
# epoch 760 / 1000: avg_val_loss =  0.00425721
# epoch 761 / 1000: avg_val_loss =  0.00446174
# epoch 762 / 1000: avg_val_loss =  0.00424044
# epoch 763 / 1000: avg_val_loss =  0.00418381
# epoch 764 / 1000: avg_val_loss =  0.00413674
# epoch 765 / 1000: avg_val_loss =  0.0044047
# epoch 766 / 1000: avg_val_loss =  0.00424137
# epoch 767 / 1000: avg_val_loss =  0.00446032
# epoch 768 / 1000: avg_val_loss =  0.00419506
# epoch 769 / 1000: avg_val_loss =  0.00433403
# epoch 770 / 1000: avg_val_loss =  0.00423812
# epoch 771 / 1000: avg_val_loss =  0.00442473
# epoch 772 / 1000: avg_val_loss =  0.00424878
# epoch 773 / 1000: avg_val_loss =  0.00436257
# epoch 774 / 1000: avg_val_loss =  0.00449505
# epoch 775 / 1000: avg_val_loss =  0.00429242
# epoch 776 / 1000: avg_val_loss =  0.00430632
# epoch 777 / 1000: avg_val_loss =  0.00425585
# epoch 778 / 1000: avg_val_loss =  0.0044012
# epoch 779 / 1000: avg_val_loss =  0.00427613
# epoch 780 / 1000: avg_val_loss =  0.00450519
# epoch 781 / 1000: avg_val_loss =  0.00427765
# epoch 782 / 1000: avg_val_loss =  0.00412525
# epoch 783 / 1000: avg_val_loss =  0.00447529
# epoch 784 / 1000: avg_val_loss =  0.0044318
# epoch 785 / 1000: avg_val_loss =  0.00444976
# epoch 786 / 1000: avg_val_loss =  0.00419046
# epoch 787 / 1000: avg_val_loss =  0.00453416
# epoch 788 / 1000: avg_val_loss =  0.0043366
# epoch 789 / 1000: avg_val_loss =  0.00436023
# epoch 790 / 1000: avg_val_loss =  0.00426929
# epoch 791 / 1000: avg_val_loss =  0.00439064
# epoch 792 / 1000: avg_val_loss =  0.00432708
# epoch 793 / 1000: avg_val_loss =  0.00461442
# epoch 794 / 1000: avg_val_loss =  0.00428082
# epoch 795 / 1000: avg_val_loss =  0.00425849
# epoch 796 / 1000: avg_val_loss =  0.00454103
# epoch 797 / 1000: avg_val_loss =  0.00418285
# epoch 798 / 1000: avg_val_loss =  0.00432386
# epoch 799 / 1000: avg_val_loss =  0.00437992
# epoch 800 / 1000: avg_val_loss =  0.00425095
# epoch 801 / 1000: avg_val_loss =  0.00445238
# epoch 802 / 1000: avg_val_loss =  0.00453632
# epoch 803 / 1000: avg_val_loss =  0.00435169
# epoch 804 / 1000: avg_val_loss =  0.00449991
# epoch 805 / 1000: avg_val_loss =  0.00416686
# epoch 806 / 1000: avg_val_loss =  0.00474267
# epoch 807 / 1000: avg_val_loss =  0.00419267
# epoch 808 / 1000: avg_val_loss =  0.00466179
# epoch 809 / 1000: avg_val_loss =  0.00428483
# epoch 810 / 1000: avg_val_loss =  0.00430033
# epoch 811 / 1000: avg_val_loss =  0.00430917
# epoch 812 / 1000: avg_val_loss =  0.00447755
# epoch 813 / 1000: avg_val_loss =  0.00434469
# epoch 814 / 1000: avg_val_loss =  0.00460756
# epoch 815 / 1000: avg_val_loss =  0.00424802
# epoch 816 / 1000: avg_val_loss =  0.0046164
# epoch 817 / 1000: avg_val_loss =  0.00424597
# epoch 818 / 1000: avg_val_loss =  0.00510144
# epoch 819 / 1000: avg_val_loss =  0.00411779
# epoch 820 / 1000: avg_val_loss =  0.00431823
# epoch 821 / 1000: avg_val_loss =  0.00450047
# epoch 822 / 1000: avg_val_loss =  0.00422302
# epoch 823 / 1000: avg_val_loss =  0.00429876
# epoch 824 / 1000: avg_val_loss =  0.00446403
# epoch 825 / 1000: avg_val_loss =  0.00430735
# epoch 826 / 1000: avg_val_loss =  0.00460197
# epoch 827 / 1000: avg_val_loss =  0.00426897
# epoch 828 / 1000: avg_val_loss =  0.0048423
# epoch 829 / 1000: avg_val_loss =  0.00415072
# epoch 830 / 1000: avg_val_loss =  0.00475839
# epoch 831 / 1000: avg_val_loss =  0.00425808
# epoch 832 / 1000: avg_val_loss =  0.00439056
# epoch 833 / 1000: avg_val_loss =  0.00436646
# epoch 834 / 1000: avg_val_loss =  0.0045296
# epoch 835 / 1000: avg_val_loss =  0.00441496
# epoch 836 / 1000: avg_val_loss =  0.00431962
# epoch 837 / 1000: avg_val_loss =  0.00450287
# epoch 838 / 1000: avg_val_loss =  0.0043454
# epoch 839 / 1000: avg_val_loss =  0.00432386
# epoch 840 / 1000: avg_val_loss =  0.00434247
# epoch 841 / 1000: avg_val_loss =  0.00418633
# epoch 842 / 1000: avg_val_loss =  0.00445424
# epoch 843 / 1000: avg_val_loss =  0.00439811
# epoch 844 / 1000: avg_val_loss =  0.00442916
# epoch 845 / 1000: avg_val_loss =  0.00427885
# epoch 846 / 1000: avg_val_loss =  0.00470515
# epoch 847 / 1000: avg_val_loss =  0.00415357
# epoch 848 / 1000: avg_val_loss =  0.00488714
# epoch 849 / 1000: avg_val_loss =  0.004073
# epoch 850 / 1000: avg_val_loss =  0.00479195
# epoch 851 / 1000: avg_val_loss =  0.00415307
# epoch 852 / 1000: avg_val_loss =  0.00482732
# epoch 853 / 1000: avg_val_loss =  0.00438519
# epoch 854 / 1000: avg_val_loss =  0.00451397
# epoch 855 / 1000: avg_val_loss =  0.00430126
# epoch 856 / 1000: avg_val_loss =  0.00433563
# epoch 857 / 1000: avg_val_loss =  0.00439825
# epoch 858 / 1000: avg_val_loss =  0.00434058
# epoch 859 / 1000: avg_val_loss =  0.00459673
# epoch 860 / 1000: avg_val_loss =  0.00425567
# epoch 861 / 1000: avg_val_loss =  0.00464857
# epoch 862 / 1000: avg_val_loss =  0.00430923
# epoch 863 / 1000: avg_val_loss =  0.00427112
# epoch 864 / 1000: avg_val_loss =  0.00463633
# epoch 865 / 1000: avg_val_loss =  0.00430998
# epoch 866 / 1000: avg_val_loss =  0.00435927
# epoch 867 / 1000: avg_val_loss =  0.00428169
# epoch 868 / 1000: avg_val_loss =  0.00431093
# epoch 869 / 1000: avg_val_loss =  0.00432802
# epoch 870 / 1000: avg_val_loss =  0.00458592
# epoch 871 / 1000: avg_val_loss =  0.00426515
# epoch 872 / 1000: avg_val_loss =  0.0046132
# epoch 873 / 1000: avg_val_loss =  0.00439951
# epoch 874 / 1000: avg_val_loss =  0.00428999
# epoch 875 / 1000: avg_val_loss =  0.00448179
# epoch 876 / 1000: avg_val_loss =  0.00425521
# epoch 877 / 1000: avg_val_loss =  0.00449857
# epoch 878 / 1000: avg_val_loss =  0.00431159
# epoch 879 / 1000: avg_val_loss =  0.00440235
# epoch 880 / 1000: avg_val_loss =  0.00467084
# epoch 881 / 1000: avg_val_loss =  0.0042382
# epoch 882 / 1000: avg_val_loss =  0.00451862
# epoch 883 / 1000: avg_val_loss =  0.00446875
# epoch 884 / 1000: avg_val_loss =  0.00437763
# epoch 885 / 1000: avg_val_loss =  0.0042658
# epoch 886 / 1000: avg_val_loss =  0.00429498
# epoch 887 / 1000: avg_val_loss =  0.00453639
# epoch 888 / 1000: avg_val_loss =  0.00446967
# epoch 889 / 1000: avg_val_loss =  0.00417888
# epoch 890 / 1000: avg_val_loss =  0.00469449
# epoch 891 / 1000: avg_val_loss =  0.00424333
# epoch 892 / 1000: avg_val_loss =  0.00435666
# epoch 893 / 1000: avg_val_loss =  0.00443111
# epoch 894 / 1000: avg_val_loss =  0.00443229
# epoch 895 / 1000: avg_val_loss =  0.00424822
# epoch 896 / 1000: avg_val_loss =  0.00434903
# epoch 897 / 1000: avg_val_loss =  0.00423329
# epoch 898 / 1000: avg_val_loss =  0.00453095
# epoch 899 / 1000: avg_val_loss =  0.00427185
# epoch 900 / 1000: avg_val_loss =  0.0042549
# epoch 901 / 1000: avg_val_loss =  0.00432786
# epoch 902 / 1000: avg_val_loss =  0.00410916
# epoch 903 / 1000: avg_val_loss =  0.00441202
# epoch 904 / 1000: avg_val_loss =  0.00476526
# epoch 905 / 1000: avg_val_loss =  0.00427633
# epoch 906 / 1000: avg_val_loss =  0.00429784
# epoch 907 / 1000: avg_val_loss =  0.0044722
# epoch 908 / 1000: avg_val_loss =  0.00438381
# epoch 909 / 1000: avg_val_loss =  0.00428893
# epoch 910 / 1000: avg_val_loss =  0.00409764
# epoch 911 / 1000: avg_val_loss =  0.00463409
# epoch 912 / 1000: avg_val_loss =  0.00419811
# epoch 913 / 1000: avg_val_loss =  0.00418724
# epoch 914 / 1000: avg_val_loss =  0.00463811
# epoch 915 / 1000: avg_val_loss =  0.0041765
# epoch 916 / 1000: avg_val_loss =  0.00444788
# epoch 917 / 1000: avg_val_loss =  0.00433705
# epoch 918 / 1000: avg_val_loss =  0.0041783
# epoch 919 / 1000: avg_val_loss =  0.00478414
# epoch 920 / 1000: avg_val_loss =  0.00406678
# epoch 921 / 1000: avg_val_loss =  0.00462456
# epoch 922 / 1000: avg_val_loss =  0.00419666
# epoch 923 / 1000: avg_val_loss =  0.00434412
# epoch 924 / 1000: avg_val_loss =  0.00427213
# epoch 925 / 1000: avg_val_loss =  0.00414908
# epoch 926 / 1000: avg_val_loss =  0.0043782
# epoch 927 / 1000: avg_val_loss =  0.00436217
# epoch 928 / 1000: avg_val_loss =  0.00420859
# epoch 929 / 1000: avg_val_loss =  0.00453534
# epoch 930 / 1000: avg_val_loss =  0.00435343
# epoch 931 / 1000: avg_val_loss =  0.00442263
# epoch 932 / 1000: avg_val_loss =  0.00427828
# epoch 933 / 1000: avg_val_loss =  0.00424159
# epoch 934 / 1000: avg_val_loss =  0.00429377
# epoch 935 / 1000: avg_val_loss =  0.00421067
# epoch 936 / 1000: avg_val_loss =  0.00437178
# epoch 937 / 1000: avg_val_loss =  0.00418616
# epoch 938 / 1000: avg_val_loss =  0.00438489
# epoch 939 / 1000: avg_val_loss =  0.00410088
# epoch 940 / 1000: avg_val_loss =  0.00462173
# epoch 941 / 1000: avg_val_loss =  0.00417735
# epoch 942 / 1000: avg_val_loss =  0.00429234
# epoch 943 / 1000: avg_val_loss =  0.0044483
# epoch 944 / 1000: avg_val_loss =  0.00458544
# epoch 945 / 1000: avg_val_loss =  0.00417771
# epoch 946 / 1000: avg_val_loss =  0.00408776
# epoch 947 / 1000: avg_val_loss =  0.00433848
# epoch 948 / 1000: avg_val_loss =  0.00472282
# epoch 949 / 1000: avg_val_loss =  0.00422208
# epoch 950 / 1000: avg_val_loss =  0.00418417
# epoch 951 / 1000: avg_val_loss =  0.00453558
# epoch 952 / 1000: avg_val_loss =  0.00426011
# epoch 953 / 1000: avg_val_loss =  0.00406693
# epoch 954 / 1000: avg_val_loss =  0.00497329
# epoch 955 / 1000: avg_val_loss =  0.0044367
# epoch 956 / 1000: avg_val_loss =  0.00430028
# epoch 957 / 1000: avg_val_loss =  0.00424361
# epoch 958 / 1000: avg_val_loss =  0.00422214
# epoch 959 / 1000: avg_val_loss =  0.00414741
# epoch 960 / 1000: avg_val_loss =  0.00454919
# epoch 961 / 1000: avg_val_loss =  0.00419947
# epoch 962 / 1000: avg_val_loss =  0.00421219
# epoch 963 / 1000: avg_val_loss =  0.00447366
# epoch 964 / 1000: avg_val_loss =  0.00409791
# epoch 965 / 1000: avg_val_loss =  0.00423117
# epoch 966 / 1000: avg_val_loss =  0.00478035
# epoch 967 / 1000: avg_val_loss =  0.00408954
# epoch 968 / 1000: avg_val_loss =  0.00443804
# epoch 969 / 1000: avg_val_loss =  0.00412395
# epoch 970 / 1000: avg_val_loss =  0.00451447
# epoch 971 / 1000: avg_val_loss =  0.00417798
# epoch 972 / 1000: avg_val_loss =  0.00434784
# epoch 973 / 1000: avg_val_loss =  0.00423948
# epoch 974 / 1000: avg_val_loss =  0.00422043
# epoch 975 / 1000: avg_val_loss =  0.00446941
# epoch 976 / 1000: avg_val_loss =  0.00409941
# epoch 977 / 1000: avg_val_loss =  0.00438413
# epoch 978 / 1000: avg_val_loss =  0.00453381
# epoch 979 / 1000: avg_val_loss =  0.00397268
# epoch 980 / 1000: avg_val_loss =  0.00421017
# epoch 981 / 1000: avg_val_loss =  0.00433145
# epoch 982 / 1000: avg_val_loss =  0.00426892
# epoch 983 / 1000: avg_val_loss =  0.00419888
# epoch 984 / 1000: avg_val_loss =  0.00465148
# epoch 985 / 1000: avg_val_loss =  0.0041242
# epoch 986 / 1000: avg_val_loss =  0.00411795
# epoch 987 / 1000: avg_val_loss =  0.00452581
# epoch 988 / 1000: avg_val_loss =  0.00450484
# epoch 989 / 1000: avg_val_loss =  0.00419472
# epoch 990 / 1000: avg_val_loss =  0.00409901
# epoch 991 / 1000: avg_val_loss =  0.00411211
# epoch 992 / 1000: avg_val_loss =  0.00420033
# epoch 993 / 1000: avg_val_loss =  0.00450101
# epoch 994 / 1000: avg_val_loss =  0.00410141
# epoch 995 / 1000: avg_val_loss =  0.00415101
# epoch 996 / 1000: avg_val_loss =  0.00426827
# epoch 997 / 1000: avg_val_loss =  0.00436791
# epoch 998 / 1000: avg_val_loss =  0.00424309
# epoch 999 / 1000: avg_val_loss =  0.00419694
# epoch 1000 / 1000: avg_val_loss =  0.00411147
#
# Best model state average validatin loss: 0.0008792321314103901

# %%
validate_model(model, validation_loader)
# Out:
# 0.0008792321314103901

# %% [markdown]
# # Plot losses from training process (given to you)

# %%
import matplotlib.pyplot as plt


iteration = np.arange(0., len(train_losses))
plt.plot(iteration, train_losses, 'g-', iteration, validation_losses, 'r-')
plt.xlabel('iterations')
plt.ylabel('loss')
plt.show()

# %% [markdown]
# # Save/Load Model (given to you)

# %%
def save(model, train_losses, validation_losses, save_dir):
    """
    saving model, train losses, and validation losses
    Args:
        model              - NN to be saved
        train_losses       - history of losses for training dataset
        validation_losses  - history of losses for validation dataset
        save_dir           - directory where to save the above
    """
    
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
    files = glob.glob(save_dir + '*')
    for f in files:
        os.remove(f) 
    
    
    torch.save(model, save_dir + "/model.dat")
    
    train_losses_f = open(save_dir + "/train_losses.txt", "wt")
    train_losses_f.writelines( "%.3f\n" % item for item in train_losses)
    
    validation_losses_f = open(save_dir + "/validation_losses.txt", "wt")
    validation_losses_f.writelines( "%.3f\n" % item for item in validation_losses)

    return
   

def load(save_dir):
    """
    loading model, train losses, and validation losses
    Args:
       save_dir  - dir name from where to load 
    """
    
    model = torch.load(save_dir + "/model.dat") 
    
    train_losses_f = open(save_dir + "/train_losses.txt", "rt")
    train_losses   = train_losses_f.readlines()
    train_losses   = [float(num) for num in train_losses]
    
    validation_losses_f = open(save_dir + "/validation_losses.txt", "rt")
    validation_losses   = validation_losses_f.readlines()
    validation_losses   = [float(num) for num in validation_losses]
    
    return (model, train_losses, validation_losses)

# %% [markdown]
# # Example saving and loading

# %%
# Create a directory, for example "./saves_12/", where you place your saved models

save(model, train_losses, validation_losses, "./saves/")

model, train_losses, validation_losses = load("./saves/")
# Out:
# D:\dev_tools\Anaconda\lib\site-packages\torch\serialization.py:360: UserWarning: Couldn't retrieve source code for container of type CircleNet. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# D:\dev_tools\Anaconda\lib\site-packages\torch\serialization.py:360: UserWarning: Couldn't retrieve source code for container of type Conv_BN_NLA. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# D:\dev_tools\Anaconda\lib\site-packages\torch\serialization.py:360: UserWarning: Couldn't retrieve source code for container of type Flatten. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# D:\dev_tools\Anaconda\lib\site-packages\torch\serialization.py:360: UserWarning: Couldn't retrieve source code for container of type Linear_BN_NLA. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %% [markdown]
# # Paint circles on loader images (given to you)

# %%
def paint_loader_circles(model, loader, out_dir):
    """
    This fucntion receives a model, a loader and an output directory. 
    For each image in the loader it paints a circle that the model identifies. 
    The images are saved in the given out_dir diretory. 
    Args:
        model   - network for idneitfying circles
        loader  - input data to use 
        out_dir - ouptut directory name (e.g.: 'draws/'). If directory does not exist, it is created.
                  If it exists, its files are deleted.
    """

    model.eval()  # eval mode (batchnorm uses moving mean/variance instead of mini-batch mean/variance)
                  # (dropout is set to zero)

    k = 0
    
    if not os.path.exists(out_dir):
        os.makedirs(out_dir)
    files = glob.glob(out_dir + '*')
    for f in files:
        os.remove(f) 
  
        
    for data in loader:
        # get inputs
        inputs = (data['image']).to(device)
        labels = (data['labels']).to(device)  # not using 
        img_fnames = data['fname'] 
      
        
        # forward
        outputs = model(inputs.float())
        curr_batch_size = np.shape(outputs)[0]
        image_size = np.shape(inputs[0])  # image_size = [3, w, h]
        _, width, height = image_size
        assert (width == height)
        
        for i in range (curr_batch_size): 
            x0 = (outputs[i, 0].item()) * width
            y0 = (1-outputs[i, 1].item()) * height
            r  = outputs[i, 2].item() * width #assume width=height here. Otherwise, circle becomes ellipse
   
            fname = img_fnames[i]
            k+=1
            print (str(k) + ".   " + fname)

            img = Image.open(fname)
            draw = ImageDraw.Draw(img, 'RGBA')
    
            draw.ellipse((x0 - r, y0 - r, x0 + r ,y0 + r), fill=(160, 64, 0, 90), outline=None)
    
            img.save(out_dir + fname.split('/')[-1])
    
        
    model.train()  #back to default
    return

# %% [markdown]
# # Example of how to paint circles produced by model

# %%
# Painting circles on images from validation loader and placing them in directory "./validation/draw/". 
# Notice that if the painted circle is seen only partly, it means that it is not inside the 
# [0,1]x[0,1] "box", which is the domain considered.  This means that your model has siginificant error


paint_loader_circles(model, validation_loader, './validation/draw/')
# Out:
# 1.   ./validation//images/0000.png
# 2.   ./validation//images/0001.png
# 3.   ./validation//images/0002.png
# 4.   ./validation//images/0003.png
# 5.   ./validation//images/0004.png
# 6.   ./validation//images/0005.png
# 7.   ./validation//images/0006.png
# 8.   ./validation//images/0007.png
# 9.   ./validation//images/0008.png
# 10.   ./validation//images/0009.png
# 11.   ./validation//images/0010.png
# 12.   ./validation//images/0011.png
# 13.   ./validation//images/0012.png
# 14.   ./validation//images/0013.png
# 15.   ./validation//images/0014.png
# 16.   ./validation//images/0015.png
# 17.   ./validation//images/0016.png
# 18.   ./validation//images/0017.png
# 19.   ./validation//images/0018.png
# 20.   ./validation//images/0019.png
# 21.   ./validation//images/0020.png
# 22.   ./validation//images/0021.png
# 23.   ./validation//images/0022.png
# 24.   ./validation//images/0023.png
# 25.   ./validation//images/0024.png
# 26.   ./validation//images/0025.png
# 27.   ./validation//images/0026.png
# 28.   ./validation//images/0027.png
# 29.   ./validation//images/0028.png
# 30.   ./validation//images/0029.png
# 31.   ./validation//images/0030.png
# 32.   ./validation//images/0031.png
# 33.   ./validation//images/0032.png
# 34.   ./validation//images/0033.png
# 35.   ./validation//images/0034.png
# 36.   ./validation//images/0035.png
# 37.   ./validation//images/0036.png
# 38.   ./validation//images/0037.png
# 39.   ./validation//images/0038.png
# 40.   ./validation//images/0039.png
# 41.   ./validation//images/0040.png
# 42.   ./validation//images/0041.png
# 43.   ./validation//images/0042.png
# 44.   ./validation//images/0043.png
# 45.   ./validation//images/0044.png
# 46.   ./validation//images/0045.png
# 47.   ./validation//images/0046.png
# 48.   ./validation//images/0047.png
# 49.   ./validation//images/0048.png
# 50.   ./validation//images/0049.png
# 51.   ./validation//images/0050.png
# 52.   ./validation//images/0051.png
# 53.   ./validation//images/0052.png
# 54.   ./validation//images/0053.png
# 55.   ./validation//images/0054.png
# 56.   ./validation//images/0055.png
# 57.   ./validation//images/0056.png
# 58.   ./validation//images/0057.png
# 59.   ./validation//images/0058.png
# 60.   ./validation//images/0059.png
# 61.   ./validation//images/0060.png
# 62.   ./validation//images/0061.png
# 63.   ./validation//images/0062.png
# 64.   ./validation//images/0063.png
# 65.   ./validation//images/0064.png
# 66.   ./validation//images/0065.png
# 67.   ./validation//images/0066.png
# 68.   ./validation//images/0067.png
# 69.   ./validation//images/0068.png
# 70.   ./validation//images/0069.png
# 71.   ./validation//images/0070.png
# 72.   ./validation//images/0071.png
# 73.   ./validation//images/0072.png
# 74.   ./validation//images/0073.png
# 75.   ./validation//images/0074.png
# 76.   ./validation//images/0075.png
# 77.   ./validation//images/0076.png
# 78.   ./validation//images/0077.png
# 79.   ./validation//images/0078.png
# 80.   ./validation//images/0079.png
# 81.   ./validation//images/0080.png
# 82.   ./validation//images/0081.png
# 83.   ./validation//images/0082.png
# 84.   ./validation//images/0083.png
# 85.   ./validation//images/0084.png
# 86.   ./validation//images/0085.png
# 87.   ./validation//images/0086.png
# 88.   ./validation//images/0087.png
# 89.   ./validation//images/0088.png
# 90.   ./validation//images/0089.png
# 91.   ./validation//images/0090.png
# 92.   ./validation//images/0091.png
# 93.   ./validation//images/0092.png
# 94.   ./validation//images/0093.png
# 95.   ./validation//images/0094.png
# 96.   ./validation//images/0095.png
# 97.   ./validation//images/0096.png
# 98.   ./validation//images/0097.png
# 99.   ./validation//images/0098.png
# 100.   ./validation//images/0099.png
